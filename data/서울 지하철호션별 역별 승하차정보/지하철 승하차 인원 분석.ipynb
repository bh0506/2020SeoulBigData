# %%
import matplotlib.pyplot as pyplot

# %%
import pandas as pd
import numpy as numpy
df = pd.read_csv('C:/Users/user/Desktop/제출서류/9월data.csv',encoding='CP949')
df
# Out:
#              호선명      지하철역  05시-06시 승차인원  05시-06시 하차인원  06시-07시 승차인원  \
# 0           우이신설  4.19민주묘지          1085           237          2715
# 1             경원        가능          7079          1734         10102
# 2            3,8      가락시장          4820          3229         10438
# 3            1,7   가산디지털단지         14359          8128         14699
# 4              9        가양         12851          1686         20376
# 5           우이신설       가오리          1889           265          5116
# 6             경의        가좌          2090           260          6421
# 7             분당       가천대          4620           658          5930
# 8             경춘        가평           679           146          1218
# 9             경인        간석          4543          1080          9640
# 10            경춘        갈매          1323           359          3702
# 11             2        강남          6632         11455         15315
# 12          7,분당      강남구청          2277          2225          5454
# ...

# %%
total = pd.read_csv('C:/Users/user/Desktop/제출서류/승하차인원.csv',encoding='CP949')
total.rename(index={0:'승차', 1:'하차'},inplace=True)
total=total.transpose()

total
# Out:
#                 승차        하차
# 05시-06시    2650829    708222
# 06시-07시    5234160   3508811
# 07시-08시   13098226   7904720
# 08시-09시   14436025  17577939
# 09시-10시    8378827  10975950
# 10시-11시    5834971   6410411
# 11시-12시    5773346   5708363
# 12시-13시    6244496   5978409
# 13시-14시    6526787   6502718
# 14시-15시    6694822   6489184
# 15시-16시    7442489   7008734
# 16시-17시    8696529   7734057
# 17시-18시   12123323  10030985
# 18시-19시   16524189  15177524
# 19시-20시    8637361  12282694
# 20시-21시    6391211   7013576
# 21시-22시    5569981   6157959
# 22시-23시    3753007   4602742

# %%
pyplot.rcParams["font.family"] = 'Malgun Gothic'
pyplot.rcParams["font.size"] = 16
pyplot.rcParams["figure.figsize"] = (20, 10)

xtext = list(total.index)

total['승차'].plot(color='#ff0000')
total['하차'].plot(color='#8046eb')
pyplot.grid()
pyplot.legend()
pyplot.title("승하차인원")
pyplot.xlabel("시간")
pyplot.ylabel("인원")



    

xpos = numpy.arange(len(total.index))

pyplot.xticks(xpos, xtext, fontsize=12)

a_max=max(total_list)
b_max=max(total_list2)

pyplot.annotate('중앙값', xy=(max(xtext),a_max), xytext=(max(xtext)+5,a_max+5),
            fontsize=14, ha='center',
            arrowprops=dict(facecolor='black', width=1, shrink=0.1, headwidth=10))


pyplot.show()
# Out:
# 22시-23시
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-6166a32a72e9> in <module>
#      22
#      23 print(max(xtext))
# ---> 24 pyplot.annotate('중앙값', xy=(max(xtext),a_max), xytext=(max(xtext)+5,a_max+5),
#      25             fontsize=14, ha='center',
#      26             arrowprops=dict(facecolor='black', width=1, shrink=0.1, headwidth=10))
#
# TypeError: can only concatenate str (not "int") to str

# %%
df.sort_index(by="08시-09시 하차인원",ascending=False)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.
#                호선명       지하철역  05시-06시 승차인원  05시-06시 하차인원  06시-07시 승차인원  \
# 3              1,7    가산디지털단지         14359          8128         14699
# 259           2,분당         선릉          4524          7077         11164
# 293            1,2         시청          2408          4961          4564
# 354            5,9        여의도          4017          3672          6395
# 357              2         역삼          3585          7034          7694
# 11               2         강남          6632         11455         15315
# 225              2         삼성          4573          4612          6183
# 402              2      을지로입구          1827          1852          2628
# 248  1,4,경부,공항철도 1         서울         14542          6705         15987
# ...
